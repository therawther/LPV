# %%
import pandas as pd
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
(X_train,y_train),(X_test,y_test)=keras.datasets.boston_housing.load_data()
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
print("Train shape: ",X_train.shape)
print("Test shape: ",X_test.shape)
print("Actual Train shape: ",y_train.shape)
print("Actual test shape: ",y_train.shape)
# Out:
# Train shape:  (404, 13)
# Test shape:  (102, 13)
# Actual Train shape:  (404,)
# Actual test shape:  (404,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from keras.layers import Dense,activation
from keras.models import Sequential

# %%
model=Sequential()
model.add(Dense(units=128,activation='relu',input_dim=(13)))
model.add(Dense(units=64,activation='relu'))
model.add(Dense(units=32,activation='relu'))
model.add(Dense(units=16,activation='relu'))
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 6s 21ms/step - loss: 547.2787
# Epoch 2/100
# 13/13 [==============================] - 0s 14ms/step - loss: 439.4961
# Epoch 3/100
# 13/13 [==============================] - 0s 11ms/step - loss: 231.4358
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 85.6353
# Epoch 5/100
# 13/13 [==============================] - 0s 7ms/step - loss: 55.8481
# Epoch 6/100
# 13/13 [==============================] - 0s 7ms/step - loss: 34.5735
# Epoch 7/100
# 13/13 [==============================] - 0s 13ms/step - loss: 26.0011
# Epoch 8/100
# 13/13 [==============================] - 0s 12ms/step - loss: 22.1751
# Epoch 9/100
# 13/13 [==============================] - 0s 12ms/step - loss: 19.5150
# Epoch 10/100
# 13/13 [==============================] - 0s 16ms/step - loss: 17.6378
# Epoch 11/100
# 13/13 [==============================] - 0s 5ms/step - loss: 16.4103
# Epoch 12/100
# ...

# %%
y_pred=model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2=r2_score(y_pred,y_test)
print("r2",r2)
# Out:
# r2 0.7958700338102132

# %%
mse=mean_squared_error(y_test,y_pred)
print("mse",mse)
# Out:
# mse 15.771573340531743

# %%
print(y_pred[5])
# Out:
# [23.295496]

# %%
input_data=np.array([[0.03237,0.0,2.18,0.0,0.458,6.998,45.8,6.0622,3.0,222.0,18.7,394.63,2.94]])
predicted_price=model.predict(input_data)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
print("prediction",predicted_price)
# Out:
# prediction [[1640.3044]]

# %%
y_pred_train=model.predict(X_train)
# Out:
# 13/13 [==============================] - 0s 2ms/step

# %%
y_pred_train[5]
# Out:
# array([18.667402], dtype=float32)
